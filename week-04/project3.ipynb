# %%
import numpy as np
import matplotlib.pyplot as plt
def walk1(n):
   x1 = 0
   y1 = 0
   xposition = [0] 
   yposition = [0] 
   for i in range (1,n+1):
       step = np.random.uniform(0,1)
       if 0 < step < 0.125:     
           x1 += 1
           y1 += 50  
       if 0.125 < step < 0.25:  
           x1 += 1
           y1 += -50
       if 0.25 < step < 0.375:     
           x1 += -1
           y1 += 50  
       if 0.375 < step < 0.5:  
           x1 += -1
           y1 += -50 
       if 0.5 < step < 0.625:     
           x1 += 50
           y1 += 1  
       if 0.625 < step < 0.75:  
           x1 += 50
           y1 += -1 
       if 0.75 < step < 0.875:     
           x1 += -50
           y1 += 1  
       if step > 0.875:  
           x1 += -50
           y1 += -1 


       xposition.append(x1)
       yposition.append(y1)
   return [xposition,yposition]


Randwalk1 = walk1(1000) 
plt.plot(Randwalk1[0],Randwalk1[1],'r-', label = "Randwalk1D") 

Randwalk2 = walk1(1000) 
plt.plot(Randwalk2[0],Randwalk2[1],'g-', label = "Randwalk1D")

Randwalk3 = walk1(1000) 
plt.plot(Randwalk3[0],Randwalk3[1],'b-', label = "Randwalk1D") 

Randwalk4 = walk1(1000) 
plt.plot(Randwalk4[0],Randwalk4[1],'y-', label = "Randwalk1D") 

plt.title("Random Walks")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

u=[]

x=[]
y=[]
s=[]
t=[]
def walk1(n):
   x1 = 0
   y1 = 0
   xposition = [0] 
   yposition = [0] 
   for i in range (1,n+1):
       step = np.random.uniform(0,1)
       if 0 < step < 0.125:     
           x1 += 1
           y1 += 50  
       if 0.125 < step < 0.25:  
           x1 += 1
           y1 += -50 
       if 0.25 < step < 0.375:     
           x1 += -1
           y1 += 50  
       if 0.375 < step < 0.5:  
           x1 += -1
           y1 += -50 
       if 0.5 < step < 0.625:     
           x1 += 50
           y1 += 1  
       if 0.625 < step < 0.75:  
           x1 += 50
           y1 += -1 
       if 0.75 < step < 0.875:     
           x1 += -50
           y1 += 1  
       if step > 0.875:  
           x1 += -50
           y1 += -1 
      

       xposition.append(x1)
       yposition.append(y1)
   x.append(x1)
   y.append(y1)
   s.append(np.sqrt(y1**2+x1**2))
   t.append(y1**2+x1**2)
   return [xposition,yposition]


#Randwalk1 = walk1(1000) 
#plt.plot(Randwalk1[0],Randwalk1[1],'r-', label = "Randwalk1D") 

#Randwalk2 = walk1(1000) 
#plt.plot(Randwalk2[0],Randwalk2[1],'g-', label = "Randwalk1D")

#Randwalk3 = walk1(1000) 
#plt.plot(Randwalk3[0],Randwalk3[1],'b-', label = "Randwalk1D") 

#plt.plot(Randwalk4[0],Randwalk4[1],'y-', label = "Randwalk1D") 

for i in range(5000):
    Randwalk1 = walk1(1000)
   
    if Randwalk1 == 0.5:
        u.append(x)
    else: 
        u.append(y)





#print(x,y,s)
plt.plot(x,y, 'o')

plt.title("ending location scatter plot")
plt.xlabel("X")
plt.ylabel("Y")



plt.show()

# %%
plt.hist(s, bins=35)
plt.title("Displacement")
plt.ylabel("Occurance")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
plt.hist(s, bins=35)
plt.semilogy()
plt.title("Displacement")
plt.ylabel("Occurance")
plt.xlabel("Distance")
plt.title("semilog")
# Out:
# Text(0.5, 1.0, 'semilog')

# %%
plt.hist(s, bins=35)
plt.loglog()
plt.title("Displacement")
plt.ylabel("Occurance")
plt.xlabel("Distance")
plt.title("log-log")
# Out:
# Text(0.5, 1.0, 'log-log')

# %%
plt.hist(t, bins=35)
plt.title("Displacement**2")
plt.ylabel("Occurance")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
plt.hist(t, bins=35)
plt.semilogy()
plt.title("Displacement")
plt.ylabel("Occurance")
plt.xlabel("Distance**2")
plt.title("semilog")
# Out:
# Text(0.5, 1.0, 'semilog')

# %%
plt.hist(t, bins=35)
plt.loglog()
plt.title("Displacement")
plt.ylabel("Occurance")
plt.xlabel("Distance**2")
plt.title("log-log")
# Out:
# Text(0.5, 1.0, 'log-log')
