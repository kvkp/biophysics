# %% [markdown]
# # Computer Lab 2
#
# Work through the "Second Computer Lab" (Chapter 7) in _A Student's Guide to Python._  This exercise illustrates how to carry out "numerical experiments" to explore theoretical models.
#
# You can use this notebook to store your code, plots, and notes, or you can write a ___script___ (see Section 3.3) that will carry out the analysis and produce the plots, and simply write your comments and observations in this notebook.  If you write a script, it should save your plot with the data and your best fit to a PDF, JPG, or PNG in this folder when it runs.

# %%
7.1

# %%
import numpy as np
import matplotlib.pyplot as plt
def walk1(n):
   x1 = 0
   y1 = 0
   xposition = [0] 
   yposition = [0] 
   for i in range (1,n+1):
       step = np.random.uniform(0,1)
       if step < 0.5:     
           x1 += 1
           y1 += -1  
       if step > 0.5:  
           x1 += -1
           y1 += 1 
       if step < 0.25:     
           x1 += 1
           y1 += 1  
       if step > 0.75:  
           x1 += -1
           y1 += -1 



       xposition.append(x1)
       yposition.append(y1)
   return [xposition,yposition]


Randwalk1 = walk1(1000) 
plt.plot(Randwalk1[0],Randwalk1[1],'r-', label = "Randwalk1D") 

Randwalk2 = walk1(1000) 
plt.plot(Randwalk2[0],Randwalk2[1],'g-', label = "Randwalk1D")

Randwalk3 = walk1(1000) 
plt.plot(Randwalk3[0],Randwalk3[1],'b-', label = "Randwalk1D") 

Randwalk4 = walk1(1000) 
plt.plot(Randwalk4[0],Randwalk4[1],'y-', label = "Randwalk1D") 

plt.title("Random Walks")
plt.show()

# %%
7.2
# Out:
# 7.2

# %%
import numpy as np
import matplotlib.pyplot as plt

u=[]

x=[]
y=[]
s=[]
t=[]
def walk1(n):
   x1 = 0
   y1 = 0
   xposition = [0] 
   yposition = [0] 
   for i in range (1,n+1):
       step = np.random.uniform(0,1)
       if step < 0.5:     
           x1 += 1
           y1 += -1  
       if step > 0.5:  
           x1 += -1
           y1 += 1 
       if step < 0.25:     
           x1 += 1
           y1 += 1  
       if step > 0.75:  
           x1 += -1
           y1 += -1 

      

       xposition.append(x1)
       yposition.append(y1)
   x.append(x1)
   y.append(y1)
   s.append(np.sqrt(y1**2+x1**2))
   t.append(y1**2+x1**2)
   return [xposition,yposition]


#Randwalk1 = walk1(1000) 
#plt.plot(Randwalk1[0],Randwalk1[1],'r-', label = "Randwalk1D") 

#Randwalk2 = walk1(1000) 
#plt.plot(Randwalk2[0],Randwalk2[1],'g-', label = "Randwalk1D")

#Randwalk3 = walk1(1000) 
#plt.plot(Randwalk3[0],Randwalk3[1],'b-', label = "Randwalk1D") 

#plt.plot(Randwalk4[0],Randwalk4[1],'y-', label = "Randwalk1D") 

for i in range(1000):
    Randwalk1 = walk1(1000)
   
    if Randwalk1 == 0.5:
        u.append(x)
    else: 
        u.append(y)





print(x,y,s)
plt.plot(x,y, 'o')

plt.title("ending location scatter plot")
plt.xlabel("X")
plt.ylabel("Y")



plt.show()
# Out:
79, -36, -51, 71, 30, 12, 31, -3, -20, 37, -26, 38, -137, 1, 70, -24, 8, 9, 3, 5, 12, -5, -13, 44, -24, -18, 35, -43, 18, -32, 86, 29, 0, 101, -58, -31, 62, -32, 5, 13, 73, -33, -16, -20, 1, 46, -40, -6, -10, 21, -55, -72, -56, -4, 17, 92, -97, -46, 28, 10, 19, 10, 100, 97, 67, 55, 18, -30, -5, -31, 20, 58, 12, -12, -30, 48, 45, 37, -18, 14, -42, -18, -56, -34, 19, -79, 69, -36, -21, -69, 60, -87, -96, -14, -57, 17, -57, 6, -15, -78, 15, 67, -19, -12, 5, -65, 115, 28, -67, -89, -14, 54, -22, -56, 18, -73, -66, -37, 1, 53, 48, 1, 96, -3, -46, 32, 6, 21, 16, 70, 3, -50, -69, -40, 32, -107, -25, -42, -37, -43, 68, -18, -43, -83, 12, 16, -76, -4, -6, 18, -3, -37, -14, -39, -18, 63, -96, -46, 3, -31, -4, -12, 23, -2, 31, 67, 1, -17, -48, 94, 27, -67, -57, -11, -50, 34, 17, 46, 24, 30, 22, 9, -50, -36, -35, -109, -56, 13, -8, -47, -8, -51, 73, -110, -69, 74, 24, -6, 5, 15, -28, -44, -128, 21, -84, -38, -34, 30, 48, 23, -3, 52, -46, 4, -66, -24, 18, 18, 17, -44, 11, 54, -49, 35, -1, 26, 79, -69, 17, 63, -26, -93, 61, 7, -15, -24, -70, 23, -21, 16, -69, -29, 92, 12, 30, -47, 9, -79, -32, 12, -18, 72, -13, -3, -13, -15, -20, 56, 30, -18, -16, -18, -27, -5, -42, -36, 92, -93, -68, 41, 1, 56, -42, 29, 35, -7, 15, 13, 15, -1, -47, 16, 37, -55, 69, -63, -70, -3, -4, 8, 41, 14, 106, 30, 40, 24, -2, -21, -3, 89, 60, -36, -58, -56, 23, 28, 15, 26, -25, -13, -8, 42, -133, -43, -25, -9, -13, -101, 0, -29, -3, 26, 18, 7, -63, -63, 11, 56, -77, -42, -56, -31, 6, -9, 9, -57, 0, 73, -42, -18, 36, 110, -78, -3, -6, 73, 66, 51, 44, 39, -119, -59,  ...

# %%
plt.hist(s, bins=35)
plt.title("Displacement")
plt.xlabel("Occurance")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
plt.hist(t, bins=35)
plt.title("Displacement")
plt.xlabel("Occurance")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
plt.semilogy(t)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("semilog")
# Out:
# Text(0.5, 1.0, 'semilog')

# %%
plt.loglog(t)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("log-log")
# Out:
# Text(0.5, 1.0, 'log-log')

# %%
w = np.mean(t)
print(w)
# Out:
# 2864.95

# %%
import numpy as np
import matplotlib.pyplot as plt

u=[]

x=[]
y=[]
s=[]
t=[]
def walk1(n):
   x1 = 0
   y1 = 0
   xposition = [0] 
   yposition = [0] 
   for i in range (1,n+1):
       step = np.random.uniform(0,1)
       if step < 0.5:     
           x1 += 1
           y1 += -1  
       if step > 0.5:  
           x1 += -1
           y1 += 1 
       if step < 0.25:     
           x1 += 1
           y1 += 1  
       if step > 0.75:  
           x1 += -1
           y1 += -1 

      

       xposition.append(x1)
       yposition.append(y1)
   x.append(x1)
   y.append(y1)
   s.append(np.sqrt(y1**2+x1**2))
   t.append(y1**2+x1**2)
   return [xposition,yposition]


#Randwalk1 = walk1(1000) 
#plt.plot(Randwalk1[0],Randwalk1[1],'r-', label = "Randwalk1D") 

#Randwalk2 = walk1(1000) 
#plt.plot(Randwalk2[0],Randwalk2[1],'g-', label = "Randwalk1D")

#Randwalk3 = walk1(1000) 
#plt.plot(Randwalk3[0],Randwalk3[1],'b-', label = "Randwalk1D") 

#plt.plot(Randwalk4[0],Randwalk4[1],'y-', label = "Randwalk1D") 

for i in range(1000):
    Randwalk1 = walk1(4000)
   
    if Randwalk1 == 0.5:
        u.append(x)
    else: 
        u.append(y)





print(x,y,s)
plt.plot(x,y, 'o')

plt.title("ending location scatter plot")
plt.xlabel("X")
plt.ylabel("Y")



plt.show()
# Out:
# [195, 8, -160, 72, 0, -17, -28, -51, 34, 130, 28, 7, 103, -195, -126, -49, -54, 26, -197, 31, -146, -107, -177, 32, -27, -191, -20, 14, 186, -109, -56, -112, 148, 212, 6, -130, -150, -8, -52, 42, -53, 196, 178, -81, 41, 155, -156, -109, -6, -76, 60, 66, -99, 164, -138, 31, 107, 99, 58, 78, 67, -123, -35, -79, 36, -15, 56, 124, -45, -155, 46, -137, 121, 48, 181, 99, 28, -4, -72, 35, -105, -192, 41, -160, -90, -114, -37, -91, -2, 31, 137, 13, -171, -10, 78, -55, 66, -33, 51, -151, -12, -64, -104, 16, 117, 83, 78, -123, -228, 39, -56, 52, -1, 61, 47, 69, -92, 51, -36, -21, -26, 1, -91, -168, 95, -115, 17, -8, -87, 24, -132, -14, -86, 103, 96, -73, -59, -44, 14, -191, -43, 50, 56, -69, 84, 27, 60, -2, 127, -20, 165, 130, -137, -80, -20, -162, -32, 39, -85, 124, -49, 30, -135, 115, 57, -94, -16, 0, 51, -68, 66, -84, -85, -28, 15, 166, -85, -52, 13, -15, -36, -108, -39, -123, -58, 53, -132, 49, -74, -86, 81, -34, 18, 54, -32, -114, -19, -100, -54, 116, -144, -89, -75, -79, 124, -80, 37, 2, -7, -2, 115, 149, 50, -70, -162, -166, 76, -102, 127, 34, 79, -155, -53, -212, -196, 102, -9, -142, -170, -159, -33, -88, -81, -181, -36, -94, -141, 18, 117, 67, -64, 95, 190, -51, -15, 178, -11, -54, 61, -133, -123, -61, -23, 20, 73, -104, 41, 63, 39, -61, 32, 138, -35, -121, -89, -3, -23, -6, -118, -35, -163, -54, -39, 15, 143, -33, -102, -76, -166, -66, 3, 15, 113, 163, 175, -52, 162, 36, 22, 42, -105, -34, -56, 142, 65, 156, -6, 152, -72, 78, -41, -128, -20, 14, -10, 14, 11, 0, -3, -110, 193, 4, -31, -44, 166, 27, 50, 42, 55, -29, 69, -57, -171, 45, -104, -27, 139, -23, 167, 119, 152, -