# %% [markdown]
# # 11.5 PENDULUM PHASE PORTRAIT
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# ## (a) Plot the phase portrait.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random



def f(Y, t):
    y1, y2 = Y
    return [y2, -np.sin(y1)-y2/3]

y1 = np.linspace(4.0, 9.0, 20)
y2 = np.linspace(-2.0, 2.0, 20)

Y1, Y2 = np.meshgrid(y1, y2)

t = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

for i in range(NI):
    for j in range(NJ):
        x = Y1[i, j]
        y = Y2[i, j]
        yprime = f([x, y], t)
        u[i,j] = yprime[0]
        v[i,j] = yprime[1]
     
plt.figure(dpi=200)
Q = plt.quiver(Y1, Y2, u, v, color='r')

# %% [markdown]
# ## (b) Describe the motion.

# %% [markdown]
# At most starting positions overshoot will occur as a spiral motion takes affect. This is similar to rolling a marble in a funnel.
