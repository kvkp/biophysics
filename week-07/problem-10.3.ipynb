# %% [markdown]
# # 10.3 RANDOM WALK WITH RANDOM WAITING TIMES
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# ## (a)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random

#rand(10)

N = 400
b = 1
u = rand(N)
u2 = rand(N)
y = -np.log(u)
y2 = -np.log(u2)
t = y/b
t2 = y2/b

#plt.plot(t,'.')


T = t.cumsum()
T2 = t2.cumsum()

#plt.vlines(T,0,1)

xi = 0.5
steps = 2*(rand(N) < xi) - 1
steps2 = 2*(rand(N) < xi) - 1
location = steps.cumsum()
location2 = steps2.cumsum()

plt.plot(T, location)
plt.plot(T2, location2)

# %% [markdown]
# ## (b)

# %%
k=[]    
trials = 50

for n in range(trials):    
    N = 400
    b = 1
    u = rand(N)
    y = -np.log(u)
    t = y/b
    T = t.cumsum()
    xi = 0.5
    steps = 2*(rand(N) < xi) - 1
    location = steps.cumsum()
    rray_length = len(location)
    last_element = location[array_length - 1]
    k.append(last_element)

    
    
#print(k)
array_length = len(k)
#print(array_length)
ave = sum(k)/len(k)
print('Sample of 50')
print('400 Second Trial')
print('average', ave)
var = np.var(k)
print('varience', var)
# Out:
# Sample of 50
# 400 Second Trial
# average -0.24
# varience 51.782399999999996

# %%
k=[]    
trials = 50

for n in range(trials):    
    N = 200
    b = 1
    u = rand(N)
    y = -np.log(u)
    t = y/b
    T = t.cumsum()
    xi = 0.5
    steps = 2*(rand(N) < xi) - 1
    location = steps.cumsum()
    rray_length = len(location)
    last_element = location[array_length - 1]
    k.append(last_element)

    
    
#print(k)
array_length = len(k)
#print(array_length)
ave = sum(k)/len(k)
print('Sample of 50')
print('200 Second Trial')
print('average', ave)
var = np.var(k)
print('varience', var)
# Out:
# Sample of 50
# 200 Second Trial
# average 0.44
# varience 48.046400000000006

# %%
k=[]    
trials = 50

for n in range(trials):    
    N = 600
    b = 1
    u = rand(N)
    y = -np.log(u)
    t = y/b
    T = t.cumsum()
    xi = 0.5
    steps = 2*(rand(N) < xi) - 1
    location = steps.cumsum()
    rray_length = len(location)
    last_element = location[array_length - 1]
    k.append(last_element)

    
    
#print(k)
array_length = len(k)
#print(array_length)
ave = sum(k)/len(k)
print('Sample of 50')
print('600 Second Trial')
print('average', ave)
var = np.var(k)
print('varience', var)
# Out:
# Sample of 50
# 600 Second Trial
# average -0.76
# varience 72.30239999999999

# %% [markdown]
# ## (c)

# %%
print('varience = ln(x) and x = sin(x)')
# Out:
# varience = ln(x) and x = sin(x)

# %% [markdown]
# ## (d)

# %%
N = 400
b = 1
u = rand(N)
u2 = rand(N)
y = -np.log(u)
y2 = -np.log(u2)
t = y/b
t2 = y2/b

#plt.plot(t,'.')


T = t.cumsum()
T2 = t2.cumsum()

#plt.vlines(T,0,1)

xi = 0.5
steps = 2*(rand(N) < xi) - 1
steps2 = 2*(rand(N) < xi) - 1
location = steps.cumsum()
location2 = steps2.cumsum()

plt.plot(location, location2)

# %% [markdown]
# ## (e)

# %%
print('animation may be beyond my level, cant even find a working program from google to get started with')

# %%
# static_plot.py

# import necessary packages
import matplotlib.pyplot as plt

# data
data_lst = [60, 59, 49, 51, 49, 52, 53]

# create the figure and axis objects
fig, ax = plt.subplots()

# plot the data and customize
ax.plot(data_lst)
ax.set_xlabel('Day Number')
ax.set_ylabel('Temperature (*F)')
ax.set_title('Temperature in Portland, OR over 7 days')

# save and show the plot
fig.savefig('static_plot.png')
plt.show()
