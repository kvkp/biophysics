# %% [markdown]
# # 10.9 SIMULATE SIMPLIFIED BURSTING PROCESS
#
# Use this notebook to store your work for this problem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 5/6
k_death = np.log(2)/50
trials = 1
N = 250
l = 0
T = 0
k = []
k0=[]
k1=[]
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
k7=[]
k8=[]
k9=[]
k10=[]
for i in range(trials):
    l = 0
    T = 0
    for n in range(N):
        rate = beta_birth + k_death * l
        t = -1/rate*np.log(rand())
        xi = beta_birth / rate
        event = rand() < xi
        if event:
            l = l+1
        else:
            l = l-1
        T = T+t
        plt.plot(T,l,'.')
        #plt.plot(T,l,'.')
        #print(T,l)
        #array_length = len(T)
        #w = array_length -1
        #point = [T,l]
        #for i in range(w):
            #location = steps.cumsum()
        #last_element = T[array_length - w]
            #for u in range(w):
        #print(point)
        #k0.append(T)
        #k1.append(l)
            
            
#x = np.linspace(10,361,360)
#x2 = np.linspace(65,361,360)
#y = 30*np.log(0.02*x)+50
#y2 = 100*(x2-60)**0.1-80

            
#print(k0)
#print(k1)
#plt.hist(k0, bins=20)
#plt.plot(k0,k1,'.')
#mean_x = np.mean((k0), axis=0)
#mean_y = np.mean((k1))
#plt.plot(mean_x,mean_y, color='black')
#plt.show()
#plt.plot(x, y, color='red')
#plt.plot(x,y2, color='green')

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 5/6
k_death = np.log(2)/50
trials = 300
N = 150
l = 0
T = [0]
k = []
k0=[]
k1=[]
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
k7=[]
k8=[]
k9=[]
k10=[]
for i in range(trials):
    l = 0
    T = 0
    for n in range(N):
        rate = beta_birth + k_death * l
        t = -1/rate*np.log(rand())
        xi = beta_birth / rate
        event = rand() < xi
        if event:
            l = l+1
        else:
            l = l-1
        T = T+t
        #plt.plot(T,l,'.')
        #plt.plot(T,l,'.')
        #print(T,l)
        #array_length = len(T)
        #w = array_length -1
        point = [T,l]
        #for i in range(w):
            #location = steps.cumsum()
        #last_element = T[array_length - w]
            #for u in range(w):
        #print(point)
        k0.append(T)
        k1.append(l)
            
            
x = np.linspace(10,150,360)
x2 = np.linspace(65,150,360)
y = 10*np.log(1*x)-10
y2 = 100*(x2-60)**0.1-110

            
#print(k0)
#print(k1)
#plt.hist(k0, bins=20)
plt.plot(k0,k1,'.')
mean_x = np.mean((k0), axis=0)
mean_y = np.mean((k1))
#plt.plot(mean_x,mean_y, color='black')
#plt.show()
plt.plot(x, y, color='red')
plt.plot(x,y2, color='green')

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 5/6
k_death = np.log(2)/50
trials = 15000
N = 150
l = 0
T = [0]
k = []
k0=[]
k1=[]
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
k7=[]
k8=[]
k9=[]
k10=[]
for i in range(trials):
    l = 0
    T = 0
    for n in range(N):
        rate = beta_birth + k_death * l
        t = -1/rate*np.log(rand())
        xi = beta_birth / rate
        event = rand() < xi
        if event:
            l = l+1
        else:
            l = l-1
        T = T+t
        #plt.plot(T,l,'.')
        #plt.plot(T,l,'.')
        #print(T,l)
        #array_length = len(T)
        #w = array_length -1
        #point = [T,l]
        #for i in range(w):
            #location = steps.cumsum()
        #last_element = T[array_length - w]
            #for u in range(w):
        #print(point)
        k0.append(T)
        k1.append(l)
            
            
#x = np.linspace(10,150,360)
#x2 = np.linspace(65,150,360)
#y = 10*np.log(1*x)-10
#y2 = 100*(x2-60)**0.1-110

            
#print(k0)
#print(k1)
plt.hist(k0, bins=20)
#plt.plot(k0,k1,'.')
#mean_x = np.mean((k0), axis=0)
#mean_y = np.mean((k1))
#plt.plot(mean_x,mean_y, color='black')
#plt.show()
#plt.plot(x, y, color='red')
#plt.plot(x,y2, color='green')

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 5/6
k_death = np.log(2)/50
trials = 1500
N = 150
l = 0
T = [0]
k = []
k0=[]
k1=[]
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
k7=[]
k8=[]
k9=[]
k10=[]
for i in range(trials):
    l = 0
    T = 0
    for n in range(N):
        rate = beta_birth + k_death * l
        t = -1/rate*np.log(rand())
        xi = beta_birth / rate
        event = rand() < xi
        if event:
            l = l+1
        else:
            l = l-1
        T = T+t
        #plt.plot(T,l,'.')
        #plt.plot(T,l,'.')
        #print(T,l)
        #array_length = len(T)
        #w = array_length -1
        #point = [T,l]
        #for i in range(w):
            #location = steps.cumsum()
        #last_element = T[array_length - w]
            #for u in range(w):
        #print(point)
        k0.append(T)
        k1.append(l)
            
            
#x = np.linspace(10,150,360)
#x2 = np.linspace(65,150,360)
#y = 10*np.log(1*x)-10
#y2 = 100*(x2-60)**0.1-110

            
#print(k0)
#print(k1)
plt.hist(k0, bins=20)
plt.semilogy()
#plt.plot(k0,k1,'.')
#mean_x = np.mean((k0), axis=0)
#mean_y = np.mean((k1))
#plt.plot(mean_x,mean_y, color='black')
#plt.show()
#plt.plot(x, y, color='red')
#plt.plot(x,y2, color='green')
# Out:
# []

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 5/6
k_death = np.log(2)/50
trials = 1500
N = 150
l = 0
T = [0]
k = []
k0=[]
k1=[]
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
k7=[]
k8=[]
k9=[]
k10=[]
for i in range(trials):
    l = 0
    T = 0
    for n in range(N):
        rate = beta_birth + k_death * l
        t = -1/rate*np.log(rand())
        xi = beta_birth / rate
        event = rand() < xi
        if event:
            l = l+1
        else:
            l = l-1
        T = T+t
        #plt.plot(T,l,'.')
        #plt.plot(T,l,'.')
        #print(T,l)
        #array_length = len(T)
        #w = array_length -1
        #point = [T,l]
        #for i in range(w):
            #location = steps.cumsum()
        #last_element = T[array_length - w]
            #for u in range(w):
        #print(point)
        k0.append(T)
        k1.append(l)
            
            
#x = np.linspace(10,150,360)
#x2 = np.linspace(65,150,360)
#y = 10*np.log(1*x)-10
#y2 = 100*(x2-60)**0.1-110

            
#print(k0)
#print(k1)
plt.hist(k0, bins=20)
plt.loglog()
#plt.plot(k0,k1,'.')
#mean_x = np.mean((k0), axis=0)
#mean_y = np.mean((k1))
#plt.plot(mean_x,mean_y, color='black')
#plt.show()
#plt.plot(x, y, color='red')
#plt.plot(x,y2, color='green')
# Out:
# []

# %% [markdown]
# first i modified the values of varius variables in a varity of ways and ran 1 program to verify its victory
#
# secondly i ran the program 300 times and fit a line to it, in this case both lines appear to fit well <l(t)>
#
# then i made a graph on a standard plot, this does not look logorithmic but more like a poisson distribution
#
# after making this plot semilog the graph still does not appear to have a trend to it
#
# after making the plot loglog it now appears to have a relativly even distribution
