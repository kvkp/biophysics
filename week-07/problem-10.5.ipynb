# %% [markdown]
# # 10.5 AVERAGE OVER MANY DRAWS
#
# Use this notebook to store your work for this problem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 1.5
k_death = 0.014
N = 900
l = 10
T = [0]

for n in range(N):
    rate = beta_birth + k_death * l
    t = -1/rate*np.log(rand())
    xi = beta_birth / rate
    event = rand() < xi
    if event:
        l = l+1
    else:
        l = l-1
    T = T+t
    plt.plot(T,l,'.')
    #print(T,l)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.special import factorial
from numpy.random import default_rng
from scipy.signal import convolve
rand = default_rng().random




l0 = 0
beta_birth = 1.5
k_death = 0.014
trials = 150
N = 900
l = 10
T = [0]
k = []
k0=[]
k1=[]
k2=[]
k3=[]
k4=[]
k5=[]
k6=[]
k7=[]
k8=[]
k9=[]
k10=[]
for i in range(trials):
    l = 10
    T = [0]
    for n in range(N):
        rate = beta_birth + k_death * l
        t = -1/rate*np.log(rand())
        xi = beta_birth / rate
        event = rand() < xi
        if event:
            l = l+1
        else:
            l = l-1
        T = T+t
        #plt.plot(T,l,'.')
        #print(T,l)
        array_length = len(T)
        #w = array_length -1
        point = [T,l]
        #for i in range(w):
            #location = steps.cumsum()
        #last_element = T[array_length - w]
            #for u in range(w):
        #print(point)
        k0.append(T)
        k1.append(l)
            
            
x = np.linspace(10,361,360)
x2 = np.linspace(65,361,360)
y = 30*np.log(0.02*x)+50
y2 = 100*(x2-60)**0.1-80

            
#print(k0)
#print(k1)
plt.plot(k0,k1,'.')
mean_x = np.mean((k0), axis=0)
mean_y = np.mean((k1))
#plt.plot(mean_x,mean_y, color='black')
#plt.show()
plt.plot(x, y, color='red')
plt.plot(x,y2, color='green')

# %% [markdown]
# I cant believe i made it this far, i hand fit an ln(x) and x**-n line as best i could, ln(x) looks much more realistic
