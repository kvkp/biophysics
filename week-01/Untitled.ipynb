# %%
import numpy as np
import matplotlib.pyplot as plt
time, population = np.loadtxt("data1.csv", delimiter = "," , unpack = True)





plt.figure(dpi=200)
plt.plot(time, population, color='green')
plt.xlabel("Year, CE")
plt.ylabel("Population, million")
plt.title("World Population")
# Out:
# Text(0.5, 1.0, 'World Population')
